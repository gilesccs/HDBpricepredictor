# %% [markdown]
# Columns:
# * year: year of resale
# * town: town the resale flat is located within
# * flat_type: the flat type of the resale flat
#     * 1 ROOM
#     * 2 ROOM
#     * 3 ROOM
#     * 4 ROOM
#     * 5 ROOM
#     * EXECUTIVE
#     * MULTI-GENERATION
# * block: block number of the resale flat
# * street_name: the street name of the resale flat
# * storey_range: the range of stories that the resale flat is on
# * floor_area_sqm
# * flat_model
#     * Improved
#     * New Generation
#     * Model A
#     * Model A2
#     * Standard
#     * Simplified
#     * Apartment
#     * Premium Apartment
#     * Maisonette
#     * Model A-Maisonette
#     * Premium Maisonette
#     * Improved-Maisonette
#     * Type S1
#     * Type S2
#     * Adjoined flat
#     * Terrace
#     * DBSS
#     * Multi Generation
#     * Premium Apartment Loft
#     * 2-room
# * lease_commence_date: year that the lease commenced
# * remaining_lease
# * resale_price
# * transaction_year
# * price_per_sqm
# * age_month
# * remaining_lease_month
# * postal
# * address
# * geometry
# * mallCount
# * busInterchangeCount
# * sportsCount
# * hawkerCount
# * npParkCount
# * preschoolCount
# * primarySchCount
# * secondarySchCount
# * tertiarySchCount
# * dist_nearestMRT
# * transaction_month

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import time

# %%
# # data = pd.read_csv('./y2015_to_2017_buffer_750.csv')
# data = pd.read_csv('./y2015_to_2017_buffer_1500.csv')

# # drop rows with any null value
# data.dropna(inplace = True)

# # drop columns:
# # geometry (for processing only)
# # remaining_lease: duplicate of remaining_lease_month
# data.drop(['geometry', 'remaining_lease', 'street_name', 'address', 'block', 'price_per_sqm', 'floor_area_sqm'], axis=1, inplace=True)

# # cleaning the month column to just keep the year
# data['month'] = data['month'].apply(lambda x: int(x[:4]))
# data.rename(columns={"month": "year"}, inplace=True)

# # cut postal code to only be first 3 digits
# data['postal'] = data['postal'].apply(lambda x: int(str(x)[:3]))

# # change storey_range to average of floors, to change categorical to numerical
# data['storey_range'] = data['storey_range'].apply(lambda x: (int(x[:2]) + int(x[-2:]))/2)
# Out:
# C:\Users\giles\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = pd.read_csv('./y2015_to_2017_buffer_1500.csv')
# data = pd.read_csv('./y2015_to_2017_buffer_750.csv')

# drop rows with any null value
data.dropna(inplace = True)

# drop columns:
# remaining_lease: 
data.drop([
    'geometry', # for processing only
    'remaining_lease', # duplicate of remaining_lease_month
    'street_name', # random
    'address',  # random
    'block', # random
    'floor_area_sqm', # feature used to create target
    'age_month', # highly correlated to remaining_lease_month
    'lease_commence_date', # var used to create remaining_lease_month
    'transaction_month', # limited use
    'resale_price', # highly correlated to target
    'month' # duplicate of transaction_date
], axis=1, inplace=True)

# # log price_per_sqm
# data['price_per_sqm'] = data['price_per_sqm'].apply(lambda x: np.log(1 + x))

# # cleaning the month column to just keep the year
# data['month'] = data['month'].apply(lambda x: int(x[:4]))
# data.rename(columns={"month": "year"}, inplace=True)

# cut postal code to only be first 3 digits
data['postal'] = data['postal'].apply(lambda x: int(str(x)[:3]))

# change storey_range to average of floors, to change categorical to numerical
data['storey_range'] = data['storey_range'].apply(lambda x: (int(x[:2]) + int(x[-2:]))/2)
# Out:
# C:\Users\giles\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#               town  flat_type  storey_range      flat_model  price_per_sqm  \
# 0       ANG MO KIO     3 ROOM           8.0        Improved        4250.00
# 1       ANG MO KIO     3 ROOM           2.0  New Generation        4044.12
# 2       ANG MO KIO     3 ROOM           2.0  New Generation        4130.43
# 3       ANG MO KIO     3 ROOM           2.0  New Generation        4130.43
# 4       ANG MO KIO     3 ROOM           2.0  New Generation        4264.71
# 5       ANG MO KIO     3 ROOM           8.0  New Generation        4264.71
# 6       ANG MO KIO     3 ROOM           8.0  New Generation        4264.71
# 7       ANG MO KIO     3 ROOM           8.0  New Generation        4328.36
# 8       ANG MO KIO     3 ROOM           2.0  New Generation        4264.71
# 9       ANG MO KIO     3 ROOM           2.0  New Generation        4308.82
# 10      ANG MO KIO     3 ROOM           2.0  New Generation        4477.61
# 11      ANG MO KIO     3 ROOM           2.0  New Generation        4477.61
# 12      ANG MO KIO     3 ROOM          14.0  New Generation        4522.06
# 13      ANG MO KIO     3 ROOM           8.0  New Generation        4597.01
# 14      ANG MO KIO     3 ROOM          11.0  New Generation        4588.24
# 15      ANG MO KIO     3 ROOM          11.0  New Generation        4588.24
# 16      ANG MO KIO     3 ROOM           8.0  New Generation        4761.19
# 17      ANG MO KIO     3 ROOM           8.0  New Generation        4776.12
# 18      ANG MO KIO     3 ROOM           8.0  New Generation        4776.12
# 19      ANG MO KIO     3 ROOM          11.0  New Generation        4779.41
# 20      ANG MO KIO     3 ROOM          11.0  New Generation        4779.41
# 21      ANG MO KIO     3 ROOM           2.0  New Generation        4391.89
# 22      ANG MO KIO     3 ROOM           8.0  New Generation        4779.41
# 23      ANG MO KIO     3 ROOM           8.0  New Generation        4925.37
# 24      ANG MO KIO     3 ROOM          11.0  New Generation        4852.94
# 25      ANG MO KIO     3 ROOM          11.0  New Generation        5000.00
# 26      ANG MO KIO     3 ROOM          11.0  New Generation        5044.78
# 27      ANG MO KIO     3 ROOM          11.0  New Generation        5074.63
# 28      ANG MO KIO     3 ROOM           5.0  New Generation        4146.34
# 29      ANG MO KIO     3 ROOM           5.0  New Generation        5014.71
# ...            ...        ...           ...             ...            ...
# 108897      YISHUN     5 ROOM          14.0        Improved        4687.50
# 108898      YISHUN     5 ROOM          14.0        Improved        4687.50
# 108899      YISHUN     5 ROOM           2.0        Improved        4214.29
# 108900      YISHUN     5 ROOM           5.0        Improved        4607.14
# 108901      YISHUN     5 ROOM           5.0        Improved        4758.93
# 108902      YISHUN     5 ROOM           5.0        Improved        4330.36
# 108903      YISHUN     5 ROOM           5.0        Improved        4401.79
# 108904      YISHUN     5 ROOM           8.0        Improved        4089.25
# 108905      YISHUN     5 ROOM           5.0        Improved        3196.72
# 108906      YISHUN     5 ROOM           5.0        Improved        3196.72
# 108907      YISHUN     5 ROOM           5.0        Improved        3786.89
# 108908      YISHUN     5 ROOM           5.0        Improved        3384.00
# 108909      YISHUN     5 ROOM           2.0        Improved        3512.40
# 108910      YISHUN     5 ROOM           2.0        Improved        3388.43
# 108911      YISHUN     5 ROOM          11.0        Improved        3760.33
# 108912      YISHUN     5 ROOM           5.0        Improved        3237.70
# 108916      YISHUN     5 ROOM           2.0        Improved        3016.53
# 108917      YISHUN     5 ROOM           5.0        Improved        3719.01
# 108918      YISHUN     5 ROOM           5.0        Improved        3868.85
# 108919      YISHUN     5 ROOM           2.0        Improved        3429.75
# 108920      YISHUN  EXECUTIVE           8.0       Apartment        3900.71
# 16                  4.0                2.0               0.0         0.497407
# 17                  4.0                3.0               1.0         0.497407
# 18                  3.0                3.0               0.0         0.497407
# 19                  5.0                5.0               1.0         0.503092
# 20                  5.0                5.0               1.0         0.503092
# 21                  3.0                3.0               1.0         0.497407
# 22                  5.0                5.0               1.0         0.307042
# 23                  3.0                5.0               2.0         1.697526
# 24                  4.0                5.0               2.0         0.752168
# 25                  4.0                3.0               0.0         0.497407
# 26                  3.0                3.0               0.0         0.497407
# 27                  5.0                8.0               2.0         0.219942
# 28                  4.0                5.0               2.0         0.752168
# 29                  3.0                5.0               1.0         0.503092
# ...                 ...                ...               ...              ...
# 108897              6.0                2.0               0.0         1.019887
# 108898              6.0                2.0               0.0         1.019887
# 108899              6.0                2.0               0.0         1.019887
# 108900              7.0                3.0               0.0         1.019887
# 108901              7.0                3.0               0.0         1.019887
# 108902              7.0                3.0               0.0         1.019887
# 108903              8.0                4.0               0.0         1.019887
# 108904              5.0                4.0               1.0         0.630638
# 108905              6.0                3.0               0.0         0.630638
# 108906              6.0                3.0               0.0         0.630638
# 108907              4.0                4.0               1.0         0.630638
# 108908              5.0                5.0               0.0         0.630638
# 108909              7.0                5.0               1.0         0.659873
# 108910              6.0                4.0               1.0         0.659873
# 108911              8.0                6.0               1.0         0.461823
# 108912              6.0                3.0               0.0         0.860349
# 108916              8.0                6.0               1.0         0.654036
# 108917              3.0                4.0               1.0         0.192997
# 108918              3.0                4.0               1.0         0.192997
# 108919              3.0                4.0               1.0         0.192997
# 108920              7.0                6.0               1.0         0.545718
# 108921              7.0                5.0               1.0         0.803612
# 108922              4.0                3.0               0.0         1.497819
# 108923              4.0                3.0               0.0         1.497819
# 108924              5.0                5.0               1.0         0.630638
# 108925              6.0                5.0               0.0         0.630638
# 108926              8.0                6.0               1.0         0.654036
# 108927              8.0                6.0               1.0         0.654036
# 108928              5.0                6.0               1.0         0.654036
# 108929              3.0                3.0               1.0         0.192997
#
#         transaction_year
# 0                   2015
# 1                   2015
# 2                   2015
# 3                   2015
# 4                   2015
# 5                   2015
# 6                   2015
# 7                   2015
# 8                   2015
# 9                   2015
# 10                  2015
# 11                  2015
# 12                  2015
# 13                  2015
# 14                  2015
# 15                  2015
# 16                  2015
# 17                  2015
# 18                  2015
# 19                  2015
# 20                  2015
# 21                  2015
# 22                  2015
# 23                  2015
# 24                  2015
# 25                  2015
# 26                  2015
# 27                  2015
# 28                  2015
# 29                  2015
# ...                  ...
# 108897              2020
# 108898              2020
# 108899              2020
# 108900              2020
# 108901              2020
# 108902              2020
# 108903              2020
# 108904              2020
# 108905              2020
# 108906              2020
# 108907              2020
# 108908              2020
# 108909              2020
# 108910              2020
# 108911              2020
# 108912              2020
# 108916              2020
# 108917              2020
# 108918              2020
# 108919              2020
# 108920              2020
# 108921              2020
# 108922              2020
# 108923              2020
# 108924              2020
# 108925              2020
# 108926              2020
# 108927              2020
# 108928              2020
# 108929              2020
#
# [106767 rows x 18 columns]

# %% [markdown]
# ## Encoding Categorical Variables
#
# * changing categorical variables into numerical ones
#
# *Source: [Python One Hot Encoding with Pandas Made Simple](http://www.insightsbot.com/python-one-hot-encoding-with-pandas-made-simple/)*

# %%
data.head()
# Out:
#          town flat_type  storey_range      flat_model  price_per_sqm  \
# 0  ANG MO KIO    3 ROOM           8.0        Improved        4250.00
# 1  ANG MO KIO    3 ROOM           2.0  New Generation        4044.12
# 2  ANG MO KIO    3 ROOM           2.0  New Generation        4130.43
# 3  ANG MO KIO    3 ROOM           2.0  New Generation        4130.43
# 4  ANG MO KIO    3 ROOM           2.0  New Generation        4264.71
#
#    remaining_lease_month  postal  mallCount  busInterchangeCount  sportsCount  \
# 0                  840.0     560        3.0                  2.0          1.0
# 1                  780.0     560        3.0                  1.0          2.0
# 2                  768.0     560        3.0                  2.0          1.0
# 3                  756.0     560        3.0                  2.0          1.0
# 4                  756.0     560        3.0                  1.0          3.0
#
#    hawkerCount  npParkCount  preschoolCount  primarySchCount  \
# 0          1.0          2.0            37.0              3.0
# 1          2.0          0.0            31.0              3.0
# 2          1.0          2.0            38.0              3.0
# 3          1.0          2.0            38.0              3.0
# 4          3.0          0.0            30.0              4.0
#
#    secondarySchCount  tertiarySchCount  dist_nearestMRT  transaction_year
# 0                5.0               2.0         1.697526              2015
# 1                2.0               1.0         0.497407              2015
# 2                6.0               2.0         1.697526              2015
# 3                6.0               2.0         1.697526              2015
# 4                3.0               0.0         0.497407              2015

# %%
# categorical_vars = ['town', 'flat_type', 'block', 'street_name', 'storey_range', 'flat_model']
categorical_vars = [['town', 'town'], ['flat_type', 'ft'], ['flat_model', 'fm']]

for cat in categorical_vars:
    data[cat[0]] = pd.Categorical(data[cat[0]])
    catDummies = pd.get_dummies(data[cat[0]], prefix = cat[1])
    data = pd.concat([data, catDummies], axis=1)
    data.drop(cat[0], axis=1, inplace=True)

# %%
data.shape
# Out:
# (106767, 68)

# %%
data.columns
# Out:
# Index(['storey_range', 'price_per_sqm', 'remaining_lease_month', 'postal',
#        'mallCount', 'busInterchangeCount', 'sportsCount', 'hawkerCount',
#        'npParkCount', 'preschoolCount', 'primarySchCount', 'secondarySchCount',
#        'tertiarySchCount', 'dist_nearestMRT', 'transaction_year',
#        'town_ANG MO KIO', 'town_BEDOK', 'town_BISHAN', 'town_BUKIT BATOK',
#        'town_BUKIT MERAH', 'town_BUKIT PANJANG', 'town_BUKIT TIMAH',
#        'town_CENTRAL AREA', 'town_CHOA CHU KANG', 'town_CLEMENTI',
#        'town_GEYLANG', 'town_HOUGANG', 'town_JURONG EAST', 'town_JURONG WEST',
#        'town_KALLANG/WHAMPOA', 'town_MARINE PARADE', 'town_PASIR RIS',
#        'town_PUNGGOL', 'town_QUEENSTOWN', 'town_SEMBAWANG', 'town_SENGKANG',
#        'town_SERANGOON', 'town_TAMPINES', 'town_TOA PAYOH', 'town_WOODLANDS',
#        'town_YISHUN', 'ft_1 ROOM', 'ft_2 ROOM', 'ft_3 ROOM', 'ft_4 ROOM',
#        'ft_5 ROOM', 'ft_EXECUTIVE', 'ft_MULTI-GENERATION', 'fm_2-room',
#        'fm_Adjoined flat', 'fm_Apartment', 'fm_DBSS', 'fm_Improved',
#        'fm_Improved-Maisonette', 'fm_Maisonette', 'fm_Model A',
#        'fm_Model A-Maisonette', 'fm_Model A2', 'fm_Multi Generation',
#        'fm_New Generation', 'fm_Premium Apartment',
#        'fm_Premium Apartment Loft', 'fm_Premium Maisonette', 'fm_Simplified',
#        'fm_Standard', 'fm_Terrace', 'fm_Type S1', 'fm_Type S2'],
#       dtype='object')

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
#Seperate datasets

X = data.drop('price_per_sqm', axis=1)
Y = data['price_per_sqm']

print(X.shape)
print(Y.shape)

X.dtypes
# Out:
# (106767, 67)
# (106767,)
# storey_range                 float64
# remaining_lease_month        float64
# postal                         int64
# mallCount                    float64
# busInterchangeCount          float64
# sportsCount                  float64
# hawkerCount                  float64
# npParkCount                  float64
# preschoolCount               float64
# primarySchCount              float64
# secondarySchCount            float64
# tertiarySchCount             float64
# dist_nearestMRT              float64
# transaction_year               int64
# town_ANG MO KIO                uint8
# town_BEDOK                     uint8
# town_BISHAN                    uint8
# town_BUKIT BATOK               uint8
# town_BUKIT MERAH               uint8
# town_BUKIT PANJANG             uint8
# town_BUKIT TIMAH               uint8
# town_CENTRAL AREA              uint8
# town_CHOA CHU KANG             uint8
# town_CLEMENTI                  uint8
# town_GEYLANG                   uint8
# town_HOUGANG                   uint8
# town_JURONG EAST               uint8
# town_JURONG WEST               uint8
# town_KALLANG/WHAMPOA           uint8
# town_MARINE PARADE             uint8
#                               ...
# town_TOA PAYOH                 uint8
# town_WOODLANDS                 uint8
# town_YISHUN                    uint8
# ft_1 ROOM                      uint8
# ft_2 ROOM                      uint8
# ft_3 ROOM                      uint8
# ft_4 ROOM                      uint8
# ft_5 ROOM                      uint8
# ft_EXECUTIVE                   uint8
# ft_MULTI-GENERATION            uint8
# fm_2-room                      uint8
# fm_Adjoined flat               uint8
# fm_Apartment                   uint8
# fm_DBSS                        uint8
# fm_Improved                    uint8
# fm_Improved-Maisonette         uint8
# fm_Maisonette                  uint8
# fm_Model A                     uint8
# fm_Model A-Maisonette          uint8
# fm_Model A2                    uint8
# fm_Multi Generation            uint8
# fm_New Generation              uint8
# fm_Premium Apartment           uint8
# fm_Premium Apartment Loft      uint8
# fm_Premium Maisonette          uint8
# fm_Simplified                  uint8
# fm_Standard                    uint8
# fm_Terrace                     uint8
# fm_Type S1                     uint8
# fm_Type S2                     uint8
# Length: 67, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

XGB = XGBRegressor()

# %%
XGB.fit(x_train,y_train)
# %time
# Out:
# C:\Users\giles\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16:00:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Wall time: 0 ns

# %%
pred_XGB = XGB.predict(x_test)
# %time
# Out:
# Wall time: 0 ns

# %%
pred_XGB
# Out:
# array([5709.0005, 4381.2417, 4067.3855, ..., 4362.625 , 4742.6104,
#        5085.0913], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
r2_score(y_test, pred_XGB)
# Out:
# 0.8595966270280248

# %%
from sklearn.metrics import r2_score
from rfpimp import permutation_importances

def r2(XGB, x_train, y_train):
    return r2_score(y_train, XGB.predict(x_train))

perm_imp_rfpimp = permutation_importances(XGB, x_train, y_train, r2)

# visualisations
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")
sns.set(rc = {'figure.figsize':(15, 10)})

# plotting a feature importance dataframe (horizontal barchart)

def var_imp_plot(imp_df, title):
    imp_df = imp_df.reset_index()
    imp_df.columns = ['feature', 'feature_importance']
    sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df, orient = 'h', color = 'royalblue').set_title(title, fontsize = 20)

var_imp_plot(perm_imp_rfpimp, 'Permutation feature importance (rfpimp)')
# Out:
# C:\Users\giles\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16:01:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
